# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np
import pymysql
pymysql.install_as_MySQLdb()

# %% [markdown]
# ### Sources of data
#
# We extracted the first data set from the Secretary of Health's website and a second data set from an open government source. The first data set consists of a catalogue containing a list of all hospitals in Mexico. The second data set corresponds to all emergencies attended in SSA hospitals in Mexico.
# The main objective of this work was to create a relational data base containing the two data sets as tables. The unifying item in both of them is "CLUES" a unique number which identifies the hospital.
# The resulting database will allow  the analysis of the number of patients admitted to public emergency rooms during 2015, the average age and sex of patients, length of stay in the emergency room, and month of admission, with the finality of determining which is the age group and gender more prone to use emergency services, the month with more admissions, and the average time patients spend in the emergency department, by making queries, using sql.
#
# For these matters, we based our analysis using the following datasets:
#
# * Establecimientos 2018 (hospital_index): http://www.dgis.salud.gob.mx/contenidos/intercambio/clues_gobmx.html
# * Urgencias 2015 (emergencies_2015): https://datos.gob.mx/busca/dataset/urgencias

# %% [markdown]
# The name of the file downloaded from  http://www.dgis.salud.gob.mx/contenidos/intercambio/clues_gobmx.html, was long and complicated. As a first step we changed the name of the first document to Establecimientos_2018. We also transformed the document to a csv format.

# %% [markdown]
# ## Data loading
# First data set

# %%
hospital_file = "Establecimientos_2018.csv"
hospitals = pd.read_csv(hospital_file, encoding='latin-1')
#hospitals = pd.read_csv(hospital_file, encoding='UTF-8)
hospitals.head()
# Out:
#          CLUES NOMBRE DE LA ENTIDAD  CLAVE DE LA ENTIDAD NOMBRE DEL MUNICIPIO  \
# 0  ASDIF000011       AGUASCALIENTES                    1       AGUASCALIENTES
# 1  ASDIF000023       AGUASCALIENTES                    1                COSÍO
# 2  ASDIF000035       AGUASCALIENTES                    1      RINCÓN DE ROMOS
# 3  ASDIF000040       AGUASCALIENTES                    1             TEPEZALÁ
# 4  ASDIF000052       AGUASCALIENTES                    1             CALVILLO
#
#    CLAVE DEL MUNICIPIO NOMBRE DE LA LOCALIDAD  CLAVE DE LA LOCALIDAD  \
# 0                    1         AGUASCALIENTES                      1
# 1                    4                  COSIO                      1
# 2                    7        RINCON DE ROMOS                      1
# 3                    9               TEPEZALA                      1
# 4                    3               CALVILLO                      1
#
#   NOMBRE DE LA JURISDICCION  CLAVE DE LA JURISDICCION  \
# 0            AGUASCALIENTES                         1
# 1           RINCÓN DE ROMOS                         2
# 2           RINCÓN DE ROMOS                         2
# 3           RINCÓN DE ROMOS                         2
# 4                  CALVILLO                         3
#
#                             NOMBRE DE LA INSTITUCION          ...            \
# 0  SISTEMA NACIONAL PARA EL DESARROLLO INTEGRAL D...          ...
# 1  SISTEMA NACIONAL PARA EL DESARROLLO INTEGRAL D...          ...
# 2  SISTEMA NACIONAL PARA EL DESARROLLO INTEGRAL D...          ...
# 3  SISTEMA NACIONAL PARA EL DESARROLLO INTEGRAL D...          ...
# 4  SISTEMA NACIONAL PARA EL DESARROLLO INTEGRAL D...          ...
#
#   CLAVE ESTRATO UNIDAD        TIPO OBRA CLAVE TIPO OBRA  HORARIO DE ATENCION  \
# 0                  2.0  NO ESPECIFICADO             6.0                  NaN
# 1                  2.0  NO ESPECIFICADO             6.0                  NaN
# 2                  2.0  NO ESPECIFICADO             6.0                  NaN
# 3                  2.0  NO ESPECIFICADO             6.0                  NaN
# 4                  2.0  NO ESPECIFICADO             6.0                  NaN
#
#   AREAS Y SERVICIOS ULTIMO MOVIMIENTO FECHA ULTIMO MOVIMIENTO  \
# 0               NaN            CAMBIO              2012-01-03
# 1               NaN            CAMBIO              2012-01-03
# 2               NaN            CAMBIO              2012-01-03
# 3               NaN            CAMBIO              2012-01-03
# 4               NaN            CAMBIO              2012-01-03
#
#   CERTIFICACION CSG  TIPO CERTIFICACION VIGENCIA CERTIFICACION
# 0    NO CERTIFICADO     NO ESPECIFICADO                    NaN
# 1    NO CERTIFICADO     NO ESPECIFICADO                    NaN
# 2    NO CERTIFICADO     NO ESPECIFICADO                    NaN
# 3    NO CERTIFICADO     NO ESPECIFICADO                    NaN
# 4    NO CERTIFICADO     NO ESPECIFICADO                    NaN
#
# [5 rows x 80 columns]

# %% [markdown]
#  Beginning with the data extraction, we filtered our datframe, and kept only rows, which correponded to hospitals:

# %%
hospitals = hospitals.loc[hospitals["NOMBRE TIPO ESTABLECIMIENTO"] == "DE HOSPITALIZACIÓN", :]
hospitals.head()
# Out:
#           CLUES NOMBRE DE LA ENTIDAD  CLAVE DE LA ENTIDAD  \
# 8   ASIMS000016       AGUASCALIENTES                    1
# 9   ASIMS000021       AGUASCALIENTES                    1
# 23  ASIMS000161       AGUASCALIENTES                    1
# 24  ASIST000016       AGUASCALIENTES                    1
# 41  ASSMP000016       AGUASCALIENTES                    1
#
#    NOMBRE DEL MUNICIPIO  CLAVE DEL MUNICIPIO NOMBRE DE LA LOCALIDAD  \
# 8        AGUASCALIENTES                    1         AGUASCALIENTES
# 9        AGUASCALIENTES                    1         AGUASCALIENTES
# 23          JESÚS MARÍA                    5    JESUS MARIA [EJIDO]
# 24       AGUASCALIENTES                    1         AGUASCALIENTES
# 41       AGUASCALIENTES                    1         AGUASCALIENTES
#
#     CLAVE DE LA LOCALIDAD NOMBRE DE LA JURISDICCION  CLAVE DE LA JURISDICCION  \
# 8                       1            AGUASCALIENTES                         1
# 9                       1            AGUASCALIENTES                         1
# 23                    469            AGUASCALIENTES                         1
# 24                      1            AGUASCALIENTES                         1
# 41                      1            AGUASCALIENTES                         1
#
#                              NOMBRE DE LA INSTITUCION          ...            \
# 8                INSTITUTO MEXICANO DEL SEGURO SOCIAL          ...
# 9                INSTITUTO MEXICANO DEL SEGURO SOCIAL          ...
# 23               INSTITUTO MEXICANO DEL SEGURO SOCIAL          ...
# 24  INSTITUTO DE SEGURIDAD Y SERVICIOS SOCIALES PA...          ...
# 41                         SERVICIOS MEDICOS PRIVADOS          ...
#
#    CLAVE ESTRATO UNIDAD        TIPO OBRA CLAVE TIPO OBRA  \
# 8                   2.0  NO ESPECIFICADO             6.0
# 9                   2.0  NO ESPECIFICADO             6.0
# 23                  2.0       OBRA NUEVA             1.0
# 24                  2.0  NO ESPECIFICADO             6.0
# 41                  2.0  NO ESPECIFICADO             6.0
#
#                                   HORARIO DE ATENCION  \
# 8                                                 NaN
# 9                                                 NaN
# 23  URGENCIAS - L,M,X,J,V,S,D, DE 00:00:00 A 12:00...
# 24                                                NaN
# 41                                                NaN
#
#                                     AREAS Y SERVICIOS ULTIMO MOVIMIENTO  \
# 8                                                 NaN            CAMBIO
# 9                                                 NaN            CAMBIO
# 23  URGENCIAS - URGENCIAS | INFECTOLOGÍA - HOSPITA...              ALTA
# 24                                                NaN            CAMBIO
# 41                                                NaN            CAMBIO
#
#    FECHA ULTIMO MOVIMIENTO CERTIFICACION CSG  TIPO CERTIFICACION  \
# 8               2015-10-08    NO CERTIFICADO     NO ESPECIFICADO
# 9               2015-10-08    NO CERTIFICADO     NO ESPECIFICADO
# 23              2018-01-06               NaN                 NaN
# 24              2015-10-08    NO CERTIFICADO     NO ESPECIFICADO
# 41              2014-01-17    NO CERTIFICADO     NO ESPECIFICADO
#
#    VIGENCIA CERTIFICACION
# 8                     NaN
# 9                     NaN
# 23                    NaN
# 24                    NaN
# 41                    NaN
#
# [5 rows x 80 columns]

# %% [markdown]
#  The finality of the data extraction was to create a relational data base.
#
# Since the file "uregencias_2015" only contains hospitals of the type SSA, we decided to filter the catalogue, so it would only contain hospitals SSA

# %%
hospitals = hospitals.loc[(hospitals["CLAVE DE LA INSTITUCION"] == "SSA")]

# %% [markdown]
# In the hospital catalogue there are some hospitals listed with 0 beds. These hospitals are in fact closed, so we removed them.

# %%
hospitals = hospitals.loc[(hospitals["TOTAL DE CAMAS"] != 0)]

# %% [markdown]
# In order to reduce the size of the dataframe, we are going to keep only columns of interest, resulting in the following data frame:

# %%
# Drop the following columns
hospitals_clean = hospitals[['CLUES', 'NOMBRE TIPO ESTABLECIMIENTO',
       'NOMBRE DE TIPOLOGIA',
       'CLAVE DE TIPOLOGIA','TOTAL DE CAMAS', 'NOMBRE DE LA UNIDAD','VIALIDAD',
       'NUMERO EXTERIOR', 'NUMERO INTERIOR',
       'CLAVE DEL TIPO DE ASENTAMIENTO', 'TIPO DE ASENTAMIENTO',
       'ASENTAMIENTO', 'CODIGO POSTAL',
       'ESTATUS DE OPERACION',
       'LONGITUD', 'LATITUD']]

# %%
hospitals_clean = hospitals_clean.rename(columns={"CLUES": "CLUES", "NOMBRE TIPO ESTABLECIMIENTO": "NOMBRE_TIPO_ESTABLECIMIENTO",
                                                  "NOMBRE DE TIPOLOGIA": "NOMBRE_DE_TIPOLOGIA", "CLAVE DE TIPOLOGIA": "CLAVE_DE_TIPOLOGIA",
                                                  "TOTAL DE CAMAS": "TOTAL_DE_CAMAS", "NOMBRE DE LA UNIDAD": "NOMBRE_DE_LA_UNIDAD",
                                                  "VIALIDAD": "VIALIDAD", "NUMERO EXTERIOR": "NUMERO_EXTERIOR", "NUMERO INTERIOR": "NUMERO_INTERIOR",
                                                  "CLAVE DEL TIPO DE ASENTAMIENTO": "CLAVE_DEL_TIPO_DE_ASENTAMIENTO", "TIPO DE ASENTAMIENTO": "TIPO_DE_ASENTAMIENTO",
                                                  "ASENTAMIENTO": "ASENTAMIENTO", "CODIGO POSTAL": "CODIGO_POSTAL", "ESTATUS DE OPERACION": "ESTATUS_DE_OPERACION",
# 8620  DFSSA004055          DE HOSPITALIZACIÓN
# 8621  DFSSA004060          DE HOSPITALIZACIÓN
# 8622  DFSSA004072          DE HOSPITALIZACIÓN
# 8623  DFSSA004084          DE HOSPITALIZACIÓN
# 8624  DFSSA004096          DE HOSPITALIZACIÓN
# 8628  DFSSA004130          DE HOSPITALIZACIÓN
# 8629  DFSSA004142          DE HOSPITALIZACIÓN
# 8630  DFSSA004154          DE HOSPITALIZACIÓN
# 8641  DFSSA004265          DE HOSPITALIZACIÓN
# 8768  DFSSA017886          DE HOSPITALIZACIÓN
#
#                   NOMBRE_DE_TIPOLOGIA CLAVE_DE_TIPOLOGIA  TOTAL_DE_CAMAS  \
# 133            HOSPITAL ESPECIALIZADO                  O             144
# 134                  HOSPITAL GENERAL                  M              60
# 135            HOSPITAL ESPECIALIZADO                  O              61
# 136             HOSPITAL PSIQUIÁTRICO                  Y              90
# 171                  HOSPITAL GENERAL                  M              30
# 192                  HOSPITAL GENERAL                  M              30
# 196                  HOSPITAL GENERAL                  M              30
# 264            HOSPITAL ESPECIALIZADO                  O             374
# 958                  HOSPITAL GENERAL                  M             174
# 1001                 HOSPITAL GENERAL                  M             129
# 1042                 HOSPITAL GENERAL                  M              47
# 1048                 HOSPITAL GENERAL                  M             189
# 1142                 HOSPITAL GENERAL                  M              35
# 1187                 HOSPITAL GENERAL                  M              80
# 1365                 HOSPITAL GENERAL                  M              46
# 1397                 HOSPITAL GENERAL                  M              98
# 1408            HOSPITAL PSIQUIÁTRICO                  Y              30
# 1423                 HOSPITAL GENERAL                  M              49
# 1457  HOSPITAL INTEGRAL (COMUNITARIO)                  N              28
# 1477                 HOSPITAL GENERAL                  M              49
# 1485                 HOSPITAL GENERAL                  M             179
# 1515                 HOSPITAL GENERAL                  M              46
# 1723           HOSPITAL ESPECIALIZADO                  O              72
# 1745            HOSPITAL PSIQUIÁTRICO                  Y              28
# 1749                 HOSPITAL GENERAL                  M              68
# 1763  HOSPITAL INTEGRAL (COMUNITARIO)                  N              22
# 1767                 HOSPITAL GENERAL                  M              28
# 1789  HOSPITAL INTEGRAL (COMUNITARIO)                  N              16
# 1799  HOSPITAL INTEGRAL (COMUNITARIO)                  N              10
# 1824  HOSPITAL INTEGRAL (COMUNITARIO)                  N              23
# ...                               ...                ...             ...
# 8531                 HOSPITAL GENERAL                  M             236
# 8552           HOSPITAL ESPECIALIZADO                  O              80
# 8553                 HOSPITAL GENERAL                  M              65
# 8568           HOSPITAL ESPECIALIZADO                  O             107
# 8569           HOSPITAL ESPECIALIZADO                  O              78
# 8570                 HOSPITAL GENERAL                  M             173
# 8581           HOSPITAL ESPECIALIZADO                  O              17
# 8585           HOSPITAL ESPECIALIZADO                  O             120
# 8586           HOSPITAL ESPECIALIZADO                  O              86
# 8587                 HOSPITAL GENERAL                  M             229
# 8609           HOSPITAL ESPECIALIZADO                  O             615
# 8610           HOSPITAL ESPECIALIZADO                  O             225
# 8611           HOSPITAL ESPECIALIZADO                  O             181
# 8612           HOSPITAL ESPECIALIZADO                  O             914
# 8614           HOSPITAL ESPECIALIZADO                  O              82
# 8615           HOSPITAL ESPECIALIZADO                  O             128
# 8616           HOSPITAL ESPECIALIZADO                  O             251
# 8617           HOSPITAL ESPECIALIZADO                  O             175
# 8618           HOSPITAL ESPECIALIZADO                  O             241
# 8619           HOSPITAL ESPECIALIZADO                  O             119
# 8620           HOSPITAL ESPECIALIZADO                  O             167
# 8621           HOSPITAL ESPECIALIZADO                  O             126
# 8622            HOSPITAL PSIQUIÁTRICO                  Y              53
# 8623           HOSPITAL ESPECIALIZADO                  O             229
# 8624           HOSPITAL ESPECIALIZADO                  O             107
# 8628            HOSPITAL PSIQUIÁTRICO                  Y             150
# 8629            HOSPITAL PSIQUIÁTRICO                  Y              95
# 8630            HOSPITAL PSIQUIÁTRICO                  Y             270
# 8641           HOSPITAL ESPECIALIZADO                  O             185
# 8768                 HOSPITAL GENERAL                  M             182
#
#                                     NOMBRE_DE_LA_UNIDAD  \
# 133                  CENTENARIO HOSPITAL MIGUEL HIDALGO
# 134                     HOSPITAL GENERAL TERCER MILENIO
# 135                                HOSPITAL DE LA MUJER
# 136   HOSPITAL DE PSIQUIATRÍA DR. GUSTAVO LEÓN MOJIC...
# 171                           HOSPITAL GENERAL CALVILLO
# 192                HOSPITAL GENERAL PABELLÓN DE ARTEAGA
# 196                    HOSPITAL GENERAL RINCÓN DE ROMOS
# 264                  CENTENARIO HOSPITAL MIGUEL HIDALGO
# 958                        HOSPITAL GENERAL DE ENSENADA
# 1001                       HOSPITAL GENERAL DE MEXICALI
# 1042                         HOSPITAL GENERAL DE TECATE
# 1048                           HOSPITAL GENERAL TIJUANA
# 1142                HOSPITAL GENERAL PLAYAS DE ROSARITO
# 1187                          HOSPITAL MATERNO INFANTIL
# 1365        HOSPITAL GENERAL RENE THOMAS GUIJOSA HABIFF
# 1397         HOSPITAL GENERAL JUAN MARÍA DE SALVATIERRA
# 1408                     HOSPITAL PSIQUIÁTRICO CHAMETLA
# 1423                 HOSPITAL GENERAL  RAÚL A. CARRILLO
# 1457                     HOSPITAL COMUNITARIO DE LORETO
# 1477                 HOSPITAL GENERAL DE CABO SAN LUCAS
# 1485  B. HOSPITAL GENERAL CON ESPECIALIDADES JUAN MA...
# 1515            HOSPITAL GENERAL DE CIUDAD CONSTITUCIÓN
# 1723           HOSPITAL ESPECIALIZADO DR. MANUEL CAMPOS
# 1745                  HOSPITAL PSIQUIÁTRICO DE CAMPECHE
# 1749                   H.G. MA. SOCORRO QUIROGA AGUILAR
# 1763                         HOSPITAL INTEGRAL SABANCUY
# 1767                      HOSPITAL GENERAL DE CHAMPOTÓN
# 1789                     HOSPITAL INTEGRAL DE HOPELCHÉN
# 1799                      HOSPITAL INTEGRAL DE PALIZADA
# 1824                           HOSPITAL INTEGRAL XPUJIL
# ...                                                 ...
# 8531                              HOSPITAL GENERAL XOCO
# 8552                     HOSPITAL PEDIÁTRICO PERALVILLO
# 1457                          CARRETERA TRANSPENINSULAR      SIN NÚMERO
# 1477                                   BLVD. LOS PINOS              S/N
# 1485                                 DE LOS DEPORTISTAS            5115
# 1515                             HUGO CERVANTES DEL RIO            S/N
# 1723                                  AVENIDA BOULEVARD      SIN NÚMERO
# 1745                  CARRETERA CAMPECHE-TENABO KM. 315      SIN NÚMERO
# 1749                                           CALLE 56      SIN NÚMERO
# 1763                                    AV. DIAZ ORDAZ       SIN NÚMERO
# 1767                      AVENIDA CARLOS SANSORES PÉREZ      SIN NÚMERO
# 1789                          CALLE 20 FRENTE AL PARQUE             448
# 1799                  IGNACIO ZARAGOZA ESQUINA CON MINA              20
# 1824                 CARRETERA  XPUJIL-DZIBALCHEN KM. 9
# ...                                                 ...             ...
# 8531       AVENIDA MÉXICO COYOACÁN ESQUINA BRUNO TRAVEN      SIN NÚMERO
# 8552                                          TOLNAHUAC              14
# 8553                                             CARMEN              42
# 8568                   ARQ. CARLOS LAZO ESQUINA GAVIOTA              25
# 8569                                    CALZADA LEGARIA             371
# 8570                      PLAN DE SAN LUIS Y DÍAZ MIRÓN             S/N
# 8581  ERNESTO P. URUCHURTU ESQUINA PROLONGACIÓN RÍO ...      SIN NÚMERO
# 8585                ESTAÑO ESQUINA CONGRESO DE LA UNIÓN            307
# 8586                                        ORIENTE 158             189
# 8587                           CECILIO RÓBELO Y SUR 103
# 8609             AVENIDA INSTITUTO POLITECNICO NACIONAL            5160
# 8610                          CALZADA MÉXICO-XOCHIMILCO             289
# 8611                                 CALZADA DE TLALPAN            4800
# 8612                                         DR. BALMIS             148
# 8614                                      CHILMALPOPOCA             135
# 8615                   PROLONGACIÓN SALVADOR DIAZ MIRON             374
# 8616                                    INSURGENTES SUR    3700 LETRA C
# 8617                                    CALZADA TLALPAN            4502
# 8618                                       JUAN BADIANO               1
# 8619                               AVENIDA SAN FERNANDO              22
# 8620                           AVENIDA VASCO DE QUIROGA              15
# 8621                            AVENIDA INSURGENTES SUR            3877
# 8622                          CALZADA MÉXICO-XOCHIMILCO             101
# 8623                                        DR. MARQUEZ             162
# 8624                                      MONTES URALES             800
# 8628                     KM.5.5 AUTOPISTA MÉXICO-PUEBLA
# 8629  AVENIDA SAN BUENAVENTURA NO. 86 COL. BELISARIO...
# 8630             NIÑO DE JESÚS ESQUINA SAN BUENAVENTURA               2
# 8641                   AVENIDA TLAHUAC ESQUINA ZACATLÁN            4866
# 8768                         PROLONGACION AV. 5 DE MAYO            3170
#
#      NUMERO_INTERIOR  CLAVE_DEL_TIPO_DE_ASENTAMIENTO TIPO_DE_ASENTAMIENTO  \
# 133              NaN                             7.0              COLONIA
# 134              NaN                             NaN                  NaN
# 135              NaN                            16.0      FRACCIONAMIENTO
# 136              NaN                             NaN                  NaN
# 171              NaN                             7.0              COLONIA
# 192              NaN                             NaN                  NaN
# 196              NaN                             NaN                  NaN
# 264              NaN                             3.0               BARRIO
# 958              NaN                             7.0              COLONIA
# 1001             NaN                             NaN                  NaN
# 1042             NaN                             NaN                  NaN
# 1723                                   CENTRO        24000.0
# 1745                                      NaN        24560.0
# 1749                                PETROLERA        24180.0
# 1763                                      NaN        24370.0
# 1767                                   ISSSTE        24400.0
# 1789                                   CENTRO        24600.0
# 1799                                   CENTRO        24200.0
# 1824                               FUNDADORES        24640.0
# ...                                       ...            ...
# 8531                            GENERAL ANAYA        99999.0
# 8552                                SAN SIMÓN        99999.0
# 8553                                   CENTRO         6020.0
# 8568                                 TACUBAYA        16870.0
# 8569                             MÉXICO NUEVO        11490.0
# 8570                     CASCO DE SANTO TOMÁS        11340.0
# 8581                      ADOLFO LÓPEZ MATEOS        99999.0
# 8585                           FELIPE ÁNGELES        15310.0
# 8586                    MOCTEZUMA 2A. SECCIÓN        15530.0
# 8587                      AERONÁUTICA MILITAR        15900.0
# 8609                 MAGDALENA DE LAS SALINAS         7760.0
# 8610                      ARENAL DE GUADALUPE        14389.0
# 8611                              SECCIÓN XVI        14080.0
# 8612                                 DOCTORES        99999.0
# 8614                                   OBRERA         6800.0
# 8615                              SANTO TOMÁS        11340.0
# 8616                    INSURGENTES CUICUILCO         4530.0
# 8617                              SECCIÓN XVI        14080.0
# 8618                              SECCIÓN XVI        14080.0
# 8619                              SECCIÓN XVI        14080.0
# 8620  COLONIA BELISARIO DOMÍNGUEZ SECCIÓN XVI        14080.0
# 8621                                  LA FAMA        14269.0
# 8622                     SAN LORENZO HUIPULCO        14370.0
# 8623                                 DOCTORES         6720.0
# 8624                           LOMAS VIRREYES        11000.0
# 8628                           SANTA CATARINA        13100.0
# 8629                                      NaN        14080.0
# 8630                                  TLALPAN        14100.0
# 8641                      SAN LORENZO TEZONCO         9790.0
# 8768           COLONIA EX-HACIENDA DE TARANGO         1618.0
#
#      ESTATUS_DE_OPERACION             LONGITUD             LATITUD
# 133    FUERA DE OPERACION          -102.296401           21.875724
# 134          EN OPERACION          -102.255516           21.855710
# 135          EN OPERACION  -102.25315632841097  21.856559459786606
# 136          EN OPERACION  -102.35532023012638  21.839200132853698
# 171          EN OPERACION  -102.70324859351354   21.84834533972848
# 192          EN OPERACION          -102.279334           22.149965
# 196          EN OPERACION          -102.321294           22.224826
# 264          EN OPERACION  -102.28305771827695  21.894723712240364
# 958          EN OPERACION               -116.6             31.8251
# 1001         EN OPERACION          -115.476271           32.644334
# 1042         EN OPERACION             -116.632             32.5577
# 1048         EN OPERACION              -117.01             32.5257
# 1142         EN OPERACION             -117.055             32.3576
# 1187         EN OPERACION             -115.382               32.62
# 1365   FUERA DE OPERACION  -111.67455285787582  25.031804361613524
# 1397   FUERA DE OPERACION         -110.3188638          24.1127408
# 1408         EN OPERACION          -110.375924          24.098264
# 1423         EN OPERACION  -109.70854595303535    23.0618656904191
# 1457         EN OPERACION          -111.364929           26.007202
# 1477         EN OPERACION  -109.92482255826553  22.902767561327053
# 1485         EN OPERACION          -110.318457           24.113297
# 1515         EN OPERACION   -111.6618657146455  25.018382835278654
# 1723         EN OPERACION             -90.5323             19.8446
# 1745         EN OPERACION           -90.419136           19.913613
# 1749         EN OPERACION   -91.82085866108537    18.6462121041991
# 1763         EN OPERACION              -91.182             18.9737
# 1767         EN OPERACION   -90.73314780369401  19.340913781756363
# 1789   FUERA DE OPERACION   -89.84449261810369  19.745393114957874
# 1799         EN OPERACION          -92.0883394          18.2550324
# 1824         EN OPERACION             -89.3973             18.5064
# ...                   ...                  ...                 ...
# 8531         EN OPERACION   -99.16236871864385  19.360121709464668
# 8552         EN OPERACION   -99.14131337787694   19.45970846621988
# 8553         EN OPERACION           -99.129455           19.437637
# 8568         EN OPERACION   -99.19081086303777  19.402548276495185
# 8569         EN OPERACION          -99.2028793          19.4508177
# 8570         EN OPERACION           -99.169030           19.451306
# 8581         EN OPERACION             -99.0693             19.4214
# 8585         EN OPERACION   -99.12413705961308  19.480653814007628
# 8586         EN OPERACION          -99.0983267          19.4329363
# 8587         EN OPERACION          -99.1170464          19.4242218
# 8609         EN OPERACION         -99.13538959         19.48210883
# 8610         EN OPERACION         -99.14869623         19.29019855
# 8611         EN OPERACION         -99.16118113         19.29084625
# 8612         EN OPERACION          -99.1151055           19.414719
# 8614         EN OPERACION          -99.1357615          19.4224891
# 8615         EN OPERACION   -99.16978234436101  19.451119787073925
# 8616         EN OPERACION   -99.18592387821263   19.30626800059771
# 8617         EN OPERACION          -99.1603748          19.2918074
# 8618         EN OPERACION          -99.1542514          19.2910955
# 8619         EN OPERACION          -99.1613638          19.2875754
# 8620         EN OPERACION          -99.1571623          19.2876757
# 8621         EN OPERACION          -99.1745625           19.291224
# 8622         EN OPERACION          -99.1549292          19.2932993
# 8623         EN OPERACION   -99.15196174766606  19.410665731443594
# 8624         EN OPERACION          -99.2052927          19.4229904
# 8628         EN OPERACION          -98.9587811          19.3211493
# 8629         EN OPERACION           -99.160351          19.2890425
# 8630         EN OPERACION          -99.1611137          19.2884105
# 8641         EN OPERACION          -99.0660984          19.3066411
# 8768         EN OPERACION      -99.2245146,186          19.3614089
#
# [172 rows x 16 columns]

# %% [markdown]
# ## Data loading
# Second data set

# %%
#File loading
urgencias = "URGENCIAS_2015.csv"
urgencias_df=pd.read_csv(urgencias, encoding='latin-1')
urgencias_df.head()
# Out:
# C:\Users\Jojo\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      ID        CLUES  FOLIO            FECHAALTA  EDAD  CVEEDAD  SEXO  \
# 0  1641  CCSSA017670   1138  2015-10-28 00:00:00    31        3     2
# 1  1642  CCSSA017670   1138  2015-12-13 00:00:00    85        3     2
# 2  1643  CCSSA017670   1139  2015-01-04 00:00:00    18        3     2
# 3  1644  CCSSA017670   1139  2015-02-03 00:00:00    42        3     2
# 4  1645  CCSSA017670   1139  2015-03-02 00:00:00    19        3     1
#
#    ENTRESIDENCIA  MUNRESIDENCIA DERHAB    ...     IRA  PLANEDA  SOBRESEDA  \
# 0              4              2      0    ...     NaN      NaN        NaN
# 1              4              2      0    ...     NaN      NaN        NaN
# 2              4              2      0    ...     NaN      NaN        NaN
# 3              4              2      0    ...     NaN      NaN        NaN
# 4              4              2      0    ...     NaN      NaN        NaN
#
#           FECHAINGRESO  HORASESTANCIA MES_ESTADISTICO  HORAINIATE MININIATE  \
# 0  2015-10-28 00:00:00              1            11.0          14        20
# 1  2015-12-13 00:00:00              1            12.0          12        50
# 2  2015-01-04 00:00:00              0             1.0           9        15
# 3  2015-02-03 00:00:00              0             2.0          21         0
# 4  2015-03-02 00:00:00              0             3.0          12        30
#
#    HORATERATE MINTERATE
# 0          15         0
# 1          13        10
# 2           9        30
# 3          21        20
# 4          12        50
#
# [5 rows x 26 columns]

# %%
#Inspecting all the columns
urgencias_df.columns.values
# Out:
# array(['ID', 'CLUES', 'FOLIO', 'FECHAALTA', 'EDAD', 'CVEEDAD', 'SEXO',
#        'ENTRESIDENCIA', 'MUNRESIDENCIA', 'DERHAB', 'TIPOURGENCIA',
#        'MOTATE', 'TIPOCAMA', 'ENVIADOA', 'MP', 'AFECPRIN', 'IRA',
#        'PLANEDA', 'SOBRESEDA', 'FECHAINGRESO', 'HORASESTANCIA',
#        'MES_ESTADISTICO', 'HORAINIATE', 'MININIATE', 'HORATERATE',
#        'MINTERATE'], dtype=object)

# %% [markdown]
# The file "urgencias", also contains a lot of columns that are not of interest. We kept only the columns valuable for the planned analysis.

# %%
emergencies_2015 = urgencias_df[['CLUES', 'FECHAALTA', 'EDAD', 'SEXO',
       'DERHAB', 'TIPOURGENCIA','MOTATE', 'TIPOCAMA', 'ENVIADOA', 'FECHAINGRESO', 'HORASESTANCIA',
       'MES_ESTADISTICO']]
emergencies_2015.head()
# Out:
#          CLUES            FECHAALTA  EDAD  SEXO DERHAB  TIPOURGENCIA  MOTATE  \
# 0  CCSSA017670  2015-10-28 00:00:00    31     2      0             1     3.0
# 1  CCSSA017670  2015-12-13 00:00:00    85     2      0             2     2.0
# 2  CCSSA017670  2015-01-04 00:00:00    18     2      0             2     2.0
# 3  CCSSA017670  2015-02-03 00:00:00    42     2      0             2     2.0
# 4  CCSSA017670  2015-03-02 00:00:00    19     1      0             1     2.0
#
#    TIPOCAMA  ENVIADOA         FECHAINGRESO  HORASESTANCIA  MES_ESTADISTICO
# 0         1         1  2015-10-28 00:00:00              1             11.0
# 1         3         2  2015-12-13 00:00:00              1             12.0
# 2         3         4  2015-01-04 00:00:00              0              1.0
# 3         3         4  2015-02-03 00:00:00              0              2.0
# 4         1         1  2015-03-02 00:00:00              0              3.0

# %% [markdown]
# ## Mysql

# %% [markdown]
# We created a database called "hospital_index" in Mysql. Within the database, two tables were creates: "emergencies_2015" and "hospitals".

# %%
#This peace of code creates the connection with data base.
engine = create_engine("mysql://root:password$.@localhost/hospital_index")

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1192                 with util.safe_reraise():
# -> 1193                     self._dec_overflow()
#    1194         else:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1189             try:
# -> 1190                 return self._create_connection()
#    1191             except:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     670             self.starttime = time.time()
# --> 671             connection = pool._invoke_creator(self)
#     672             pool.logger.debug("Created new connection %r", connection)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     409     def connect(self, *cargs, **cparams):
# --> 410         return self.dbapi.connect(*cargs, **cparams)
#     411
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymysql\__init__.py in Connect(*args, **kwargs)
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymysql\connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     324         else:
# --> 325             self.connect()
#     326
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     598             self._get_server_information()
# --> 599             self._request_authentication()
#     600
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymysql\connections.py in _request_authentication(self)
#     860         self.write_packet(data)
# --> 861         auth_packet = self._read_packet()
#     862
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymysql\protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# OperationalError: (1045, "Access denied for user 'root'@'localhost' (using password: YES)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-13-d72bc75a6b62> in <module>()
# ----> 1 engine.table_names()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in table_names(self, schema, connection)
#    2134         """
#    2135
# -> 2136         with self._optional_conn_ctx_manager(connection) as conn:
#    2137             if not schema:
#    2138                 schema = self.dialect.default_schema_name
#
# ~\Anaconda3\envs\PythonData\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _optional_conn_ctx_manager(self, connection)
#    1930     def _optional_conn_ctx_manager(self, connection=None):
#    1931         if connection is None:
# -> 1932             with self.contextual_connect() as conn:
#    1933                 yield conn
#    1934         else:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in contextual_connect(self, close_with_result, **kwargs)
#    2121         return self._connection_cls(
#    2122             self,
# -> 2123             self._wrap_pool_connect(self.pool.connect, None),
#    2124             close_with_result=close_with_result,
#    2125             **kwargs)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2160             if connection is None:
#    2161                 Connection._handle_dbapi_exception_noconnection(
# -> 2162                     e, dialect, self)
#    2163             else:
#    2164                 util.reraise(*sys.exc_info())
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1474             util.raise_from_cause(
#    1475                 sqlalchemy_exception,
# -> 1476                 exc_info
#    1477             )
#    1478         else:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2156         dialect = self.dialect
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#    2160             if connection is None:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     401         """
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#     405         try:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     786     def _checkout(cls, pool, threadconns=None, fairy=None):
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#     790             fairy._pool = pool
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     530     @classmethod
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#     534             dbapi_connection = rec.get_connection()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1191             except:
#    1192                 with util.safe_reraise():
# -> 1193                     self._dec_overflow()
#    1194         else:
#    1195             return self._do_get()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      64             self._exc_info = None   # remove potential circular references
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#      68             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     185         if value.__traceback__ is not tb:
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#     189 else:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1188         if self._inc_overflow():
#    1189             try:
# -> 1190                 return self._create_connection()
#    1191             except:
#    1192                 with util.safe_reraise():
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     348         """Called by subclasses to create a new ConnectionRecord."""
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#     352     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     475         self.__pool = pool
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#     479
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     669         try:
#     670             self.starttime = time.time()
# --> 671             connection = pool._invoke_creator(self)
#     672             pool.logger.debug("Created new connection %r", connection)
#     673             self.connection = connection
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     104                         if connection is not None:
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#     108             creator = pop_kwarg('creator', connect)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     408
#     409     def connect(self, *cargs, **cparams):
# --> 410         return self.dbapi.connect(*cargs, **cparams)
#     411
#     412     def create_connect_args(self, url):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymysql\__init__.py in Connect(*args, **kwargs)
#      92     """
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#      96 from . import connections as _orig_conn
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymysql\connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     323             self._sock = None
#     324         else:
# --> 325             self.connect()
#     326
#     327     def _create_ssl_ctx(self, sslp):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     597
#     598             self._get_server_information()
# --> 599             self._request_authentication()
#     600
#     601             if self.sql_mode is not None:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymysql\connections.py in _request_authentication(self)
#     859
#     860         self.write_packet(data)
# --> 861         auth_packet = self._read_packet()
#     862
#     863         # if authentication method isn't accepted the first byte
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymysql\protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1045, "Access denied for user 'root'@'localhost' (using password: YES)") (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
#emergencies_2015.to_sql(name='emergencies_2015', con=engine, if_exists='append', index=False)
emergencies_2015.to_csv("emergencies_2015_clean.csv", encoding = "latin-1", index=False, header=True)

# %%
hospitals_clean.to_sql(name='hospitals', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\AlejandroDorantes\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py:1166: UserWarning: The provided table name 'Establecimientos1' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
